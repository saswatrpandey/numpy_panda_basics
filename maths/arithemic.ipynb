# %%
from IPython.display import display, Math

# %%
display(f'4+3 = {4+3}')
# Out:
# '4+3 = 7'

# %%
display(Math('4+3=7'))
# Out:
# $\displaystyle 4+3=7$

# %%
x = 1
y = 2
display(Math(f'x+y={x+y}'))
# Out:
# $\displaystyle x+y=3$

# %%
display(Math(f'\\frac{4}{5} = {4/5}'))
# Out:
# $\displaystyle \frac45 = 0.8$

# %%
x= 7
y = -2
z = 5

display(Math((f'-y - \\frac{{x+3}}{{z}} = {{{-y-((x+3)/z)}}}')))
# Out:
# $\displaystyle -y - \frac{x+3}{z} = {0.0}$

# %%
x = 5
y = 5.1

display(Math(f'x^\\frac{{3}}{{4}} \\times 4^y = {{{x**(3/4) * 4**y}}}'))
# Out:
# $\displaystyle x^\frac{3}{4} \times 4^y = {3933.086147822751}$

# %% [markdown]
# Absolute Value
# is the distance of the number to the origin of the number line.

# %%
abs(-2.66)
# Out:
# 2.66

# %%
x = -4.3
display(Math(f'|{{{x}}}| = {{{abs(x)}}}'))
# Out:
# $\displaystyle |{-4.3}| = {4.3}$

# %%
#modulus
a = 88
b = 7

a%b
# Out:
# 4
